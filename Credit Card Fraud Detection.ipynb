# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('F:\Data_Science\CreditCard\CreditCardFraud.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(df['Class'])
plt.xlabel('0:Normal,  1:Fraud',color='r')
# Out:
# Text(0.5, 0, '0:Normal,  1:Fraud')

# %%
df['Class'].value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %%
# Only 017% transactions are Fraud

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df['Time']
# Out:
# 0              0.0
# 1              0.0
# 2              1.0
# 3              1.0
# 4              2.0
#             ...
# 284802    172786.0
# 284803    172787.0
# 284804    172788.0
# 284805    172788.0
# 284806    172792.0
# Name: Time, Length: 284807, dtype: float64

# %%
df['Time_Hour']=df['Time']/3600

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
#         V27       V28  Amount  Class  Time_Hour
# 0  0.133558 -0.021053  149.62      0   0.000000
# 1 -0.008983  0.014724    2.69      0   0.000000
# 2 -0.055353 -0.059752  378.66      0   0.000278
# 3  0.062723  0.061458  123.50      0   0.000278
# 4  0.219422  0.215153   69.99      0   0.000556
#
# [5 rows x 32 columns]

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Time_Hour'],bins=48,kde=False)
plt.xlim([0,48])
plt.xticks(np.arange(0,54,6))
plt.xlabel('Time After First Transaction (hr)')
plt.ylabel('Count')
plt.title('Transaction Times')
# Out:
# Text(0.5, 1.0, 'Transaction Times')

# %%
df['Amount']
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 284807, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=70)
sns.distplot(df['Amount'], bins=100, kde=False)
plt.ylabel('Count')
plt.title('Transaction Amounts')
# Out:
# Text(0.5, 1.0, 'Transaction Amounts')

# %%
df['Amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
df[df['Amount']>10000]
# Out:
#             Time         V1         V2         V3         V4          V5  \
# 46841    42951.0 -23.712839 -42.172688 -13.320825   9.925019  -13.945538
# 54018    46253.0 -21.780665 -38.305310 -12.122469   9.752791  -12.880794
# 58465    48401.0 -36.802320 -63.344698 -20.645794  16.715537  -20.672064
# 151296   95286.0 -34.549296 -60.464618 -21.340854  16.875344  -19.229075
# 169457  119713.0 -20.924897 -37.943452 -14.060281  10.473005  -10.866639
# 274771  166198.0 -35.548539 -31.850484 -48.325589  15.304184 -113.743307
# 284249  172273.0  -9.030538 -11.112584 -16.233798   3.592021  -40.427726
#
#                V6          V7         V8        V9  ...        V22        V23  \
# 46841    5.564891   15.710644  -2.844253 -1.580725  ...  -6.320710 -11.310338
# 54018    4.256017   14.785051  -2.818253 -0.667338  ...  -5.619439 -10.547038
# 58465    7.694002   24.956587  -4.730111 -2.687312  ... -10.933144 -17.173665
# 151296   6.335259   24.422716  -4.964566  0.188912  ...  -9.499423 -16.513186
# 169457   6.256654   14.960521  -2.392155 -0.597076  ...  -6.926353  -9.928657
# 274771  73.301626  120.589494 -27.347360 -3.872425  ...   5.712303  -1.581098
# 284249  23.917837   44.054461  -7.277778 -4.210637  ...   0.988144   7.040028
#
#              V24       V25       V26        V27        V28    Amount  Class  \
# 46841   0.404175 -4.547278 -1.577118  -2.357385   2.253662  12910.93      0
# 54018   0.653249 -4.232409 -0.480459  -2.257913   2.082488  11898.09      0
# 58465   1.180700 -7.025783 -2.534330  -3.602479   3.450224  19656.53      0
# 151296  0.744341 -7.081325 -2.604551  -3.550963   3.250802  18910.00      0
# 169457 -0.447084 -4.848151 -2.241620  -2.140723   2.001492  11789.84      0
# 274771  4.584549  4.554683  3.415636  31.612198 -15.430084  25691.16      0
# 284249  0.347693  2.520869  2.342495   3.478175  -2.713136  10199.44      0
#
#         Time_Hour
# 46841   11.930833
# 54018   12.848056
# 58465   13.444722
# 151296  26.468333
# 169457  33.253611
# 274771  46.166111
# 284249  47.853611
#
# [7 rows x 32 columns]

# %%
sns.lmplot(y="Amount", x="Time_Hour", fit_reg=False,aspect=1.8,data=df,hue='Class')
plt.title("Amounts by Hour of Frauds and Normal Transactions",fontsize=14,color='r')
plt.show()

# %%
sns.boxplot(x=df['Amount'])

# %%
sns.relplot(x='Class',y='Amount',data=df)

# %%
df.drop('Time',axis=1,inplace=True)

# %%
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V22       V23  \
# 0       0.239599  0.098698  0.363787  0.090794  ...  0.277838 -0.110474
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.771679  0.909412
# 3       0.237609  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321
# 4       0.592941 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.111864  1.014480
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.924384  0.012463
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.578229 -0.037501
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.800049 -0.163298
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.643078  0.376777
#
#              V24       V25       V26       V27       V28  Amount  Class  \
# 0       0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1      -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2      -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3      -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4       0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 284802 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77      0
# 284803 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79      0
# 284804  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88      0
# 284805  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00      0
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00      0
#
#         Time_Hour
# 0        0.000000
# 1        0.000000
# 2        0.000278
# 3        0.000278
# 4        0.000556
# ...           ...
# 284802  47.996111
# 284803  47.996389
# 284804  47.996667
# 284805  47.996667
# 284806  47.997778
#
# [284807 rows x 31 columns]

# %%
X_data=df.drop('Class',axis=1)
y_data=df['Class']

# %%
X_data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# 0       0.239599  0.098698  0.363787  0.090794  ... -0.018307  0.277838
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.247998  0.771679
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274
# 4       0.592941 -0.270533  0.817739  0.753074  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.213454  0.111864
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.214205  0.924384
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.232045  0.578229
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.265245  0.800049
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Time_Hour
# 0        0.000000
# 1        0.000000
# 2        0.000278
# 3        0.000278
# 4        0.000556
# ...           ...
# 284802  47.996111
# 284803  47.996389
# 284804  47.996667
# 284805  47.996667
# 284806  47.997778
#
# [284807 rows x 30 columns]

# %%
y_data
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
# Important feature using ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesClassifier
selection = ExtraTreesClassifier()
selection.fit(X_data, y_data)
# Out:
# ExtraTreesClassifier()

# %%
print(selection.feature_importances_)
# Out:
# [0.01293167 0.01602099 0.03548866 0.04082184 0.01448633 0.01342493
#  0.02313735 0.01471548 0.0323104  0.06726747 0.08023145 0.13793878
#  0.01236579 0.11622742 0.01191132 0.06328195 0.11648143 0.03634965
#  0.01431192 0.01268695 0.01459618 0.01217531 0.0099505  0.01218941
#  0.01091715 0.01293924 0.01439624 0.01240821 0.01142659 0.01660942]

# %%
plt.figure(figsize=(15,15))
feat_imp=pd.Series(selection.feature_importances_,index=X_data.columns)
feat_imp.sort_values(ascending=False).plot(kind='barh')

# %%
feat_imp.sort_values(ascending=False).index
# Out:
# Index(['V12', 'V17', 'V14', 'V11', 'V10', 'V16', 'V4', 'V18', 'V3', 'V9', 'V7',
#        'Time_Hour', 'V2', 'V8', 'V21', 'V5', 'V27', 'V19', 'V6', 'V26', 'V1',
#        'V20', 'V28', 'V13', 'V24', 'V22', 'V15', 'Amount', 'V25', 'V23'],
#       dtype='object')

# %%
df_final=df.loc[:,['V12', 'V17', 'V14', 'V11', 'V10', 'V16', 'V4', 'V18', 'V3', 'V9', 'V7','Class']]

# %%
X=df_final.drop('Class',axis=1)
X
# Out:
#              V12       V17       V14       V11       V10       V16        V4  \
# 0      -0.617801  0.207971 -0.311169 -0.551600  0.090794 -0.470401  1.378155
# 1       1.065235 -0.114805 -0.143772  1.612727 -0.166974  0.463917  0.448154
# 2       0.066084  1.109969 -0.165946  0.624501  0.207643 -2.890083  0.379780
# 3       0.178228 -0.684093 -0.287924 -0.226487 -0.054952 -1.059647 -0.863291
# 4       0.538196 -0.237033 -1.119670 -0.822843  0.753074 -0.451449  0.403034
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  2.711941  1.991691  4.626942 -1.593105  4.356170  1.107641 -2.066656
# 284803  0.915802 -0.025693 -0.675143 -0.150189 -0.975926 -0.711757 -0.738589
# 284804  0.063119  0.313502 -0.510602  0.411614 -0.484782  0.140716 -0.557828
# 284805 -0.962886  0.509928  0.449624 -1.933849 -0.399126 -0.608577  0.689799
# 284806 -0.031513 -0.660377 -0.084316 -1.040458 -0.915427 -0.302620 -0.506271
#
#              V18        V3        V9        V7
# 0       0.025791  2.536347  0.363787  0.239599
# 1      -0.183361  0.166480 -0.255425 -0.078803
# 2      -0.121359  1.773209 -1.514654  0.791461
# 3       1.965775  1.792993 -1.387024  0.237609
# 4      -0.038195  1.548718  0.817739  0.592941
# ...          ...       ...       ...       ...
# 284802  0.510632 -9.834783  1.914428 -4.918215
# 284803 -1.221179  2.035030  0.584800  0.024330
# 284804  0.395652 -3.249640  0.432454 -0.296827
# 284805  1.113981  0.702510  0.392087 -0.686180
# 284806  0.167430  0.703337  0.486180  1.577006
#
# [284807 rows x 11 columns]

# %%
y=df_final['Class']

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
sns.relplot(x='V17',y='V12',hue='Class',data=df,palette='magma')

# %%
sns.relplot(x='V17',y='V14',hue='Class',data=df)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
s=StandardScaler()
X_train=s.fit_transform(X_train)
X_test=s.transform(X_test)

# %%
value=[]
algo=[]
def cross_val_score_model(model,name):
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=10)
    cv_score=cross_val_score(model,X,y,cv=cv).mean()
    print('CV_Score' + ' '+ str(name) +': '+ str(cv_score))
    value.append(cv_score)
    algo.append(name)

cross_val_score_model(LogisticRegression(solver='liblinear',multi_class='auto'),'Logistic Regression')
# Out:
# CV_Score Logistic Regression: 0.9991854218601874

# %%
df_final[df_final['Class']==1]
# Out:
#               V12        V17       V14       V11       V10       V16  \
# 541     -2.899907  -2.830056 -4.289254  3.202033 -2.772272 -1.140747
# 623     -0.503141   0.599717 -1.692029 -0.414575 -0.838587  0.666780
# 4920    -6.560124  -4.781831 -1.470102  2.032912 -1.525412 -2.282194
# 6108   -10.912819 -12.598419 -6.771097  4.895844 -4.801637 -7.358083
# 6329    -4.609628   6.739384 -6.079337  2.101344 -2.447469  2.581851
# ...           ...        ...       ...       ...       ...       ...
# 279863  -5.417424  -4.570529 -6.665177  2.115795 -5.587794 -2.897825
# 280143  -3.096915  -3.267116 -5.210141  2.858466 -3.232153 -2.155297
# 280149  -2.775022  -5.035326 -4.057162  1.794969 -3.463891 -1.603015
# 281144  -5.030465  -4.614717 -6.416628  1.933520 -5.245984 -2.549498
# 281674   0.728903   0.903562 -1.948883  0.491140 -0.888722  0.519436
#
#               V4       V18        V3        V9        V7  Class
# 541     3.997906 -0.016822 -1.609851 -2.770089 -2.537387      1
# 623     2.288644  1.725321  1.088463 -0.270953  0.325574      1
# 4920    2.330243 -2.615665 -0.359745 -0.238253  0.562320      1
# 6108    2.679787 -5.131549 -2.592844 -0.247768 -3.496197      1
# 6329    4.732795  3.042493 -4.304597 -1.282858  1.713445      1
# ...          ...       ...       ...       ...       ...    ...
# 279863  1.749293 -1.315147 -4.518331 -2.064945 -0.882850      1
# 280143  1.411850 -0.688505 -5.004247 -1.127396 -1.413170      1
# 280149  0.468308 -0.507000 -2.213700 -0.652250 -2.234739      1
# 281144  1.817092 -1.478138 -5.399730 -1.632333 -2.208002      1
# 281674  0.408670  1.197315 -2.583441  0.577829  0.223050      1
#
# [492 rows x 12 columns]

# %%
from sklearn.metrics import accuracy_score
lr=LogisticRegression(solver='liblinear',multi_class='auto')
lr.fit(X_train,y_train)
lr_y_pred=lr.predict(X_test)
score=accuracy_score(y_test,lr_y_pred)
score
# Out:
# 0.9993328885923949

# %%
df_final.iloc[45203]
# Out:
# V12      -5.849558
# V17       0.635694
# V14     -11.583898
# V11       4.389214
# V10      -4.077585
# V16      -1.461029
# V4        6.456588
# V18       0.390150
# V3       -4.946075
# V9       -3.649812
# V7       -0.184710
# Class     1.000000
# Name: 45203, dtype: float64

# %%
a=[[5.849558,0.635694,-11.583898,4.389214,-4.077585,-1.461029,6.456588,0.390150,-4.946075,-3.649812,-0.184710]]
a=s.transform(a)
b=lr.predict(a)
b
# Out:
# array([1], dtype=int64)

# %%
final=pd.DataFrame({'actual':y_test,
                   'predictions':lr_y_pred})

# %%
final
# Out:
#         actual  predictions
# 168367       0            0
# 110270       0            0
# 243562       0            0
# 74702        0            0
# 98416        0            0
# ...        ...          ...
# 201941       0            0
# 244413       0            0
# 50907        0            0
# 240691       0            0
# 79068        0            0
#
# [56962 rows x 2 columns]

# %%
len(final[(final['actual']==1)& (final['predictions']==0)])
# Out:
# 31
