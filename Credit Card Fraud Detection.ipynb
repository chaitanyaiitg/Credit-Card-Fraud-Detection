# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('F:\Data_Science\CreditCard\CreditCardFraud.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(df['Class'])
plt.xlabel('0:Normal,  1:Fraud',color='r')
# Out:
# Text(0.5, 0, '0:Normal,  1:Fraud')

# %%
df['Class'].value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %%
# Only 017% transactions are Fraud

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df['Time']
# Out:
# 0              0.0
# 1              0.0
# 2              1.0
# 3              1.0
# 4              2.0
#             ...
# 284802    172786.0
# 284803    172787.0
# 284804    172788.0
# 284805    172788.0
# 284806    172792.0
# Name: Time, Length: 284807, dtype: float64

# %%
df['Time_Hour']=df['Time']/3600

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Time_Hour'],bins=48,kde=False)
plt.xlim([0,48])
plt.xticks(np.arange(0,54,6))
plt.xlabel('Time After First Transaction (hr)')
plt.ylabel('Count')
plt.title('Transaction Times')
# Out:
# Text(0.5, 1.0, 'Transaction Times')

# %%
df['Amount']
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 284807, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=70)
sns.distplot(df['Amount'], bins=100, kde=False)
plt.ylabel('Count')
plt.title('Transaction Amounts')
# Out:
# Text(0.5, 1.0, 'Transaction Amounts')

# %%
df['Amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
df[df['Amount']>10000]
# Out:
#             Time         V1         V2         V3         V4          V5  \
# 46841    42951.0 -23.712839 -42.172688 -13.320825   9.925019  -13.945538
# 54018    46253.0 -21.780665 -38.305310 -12.122469   9.752791  -12.880794
# 58465    48401.0 -36.802320 -63.344698 -20.645794  16.715537  -20.672064
# 151296   95286.0 -34.549296 -60.464618 -21.340854  16.875344  -19.229075
# 169457  119713.0 -20.924897 -37.943452 -14.060281  10.473005  -10.866639
# 274771  166198.0 -35.548539 -31.850484 -48.325589  15.304184 -113.743307
# 284249  172273.0  -9.030538 -11.112584 -16.233798   3.592021  -40.427726
#
#                V6          V7         V8        V9  ...        V22        V23  \
# 46841    5.564891   15.710644  -2.844253 -1.580725  ...  -6.320710 -11.310338
# 54018    4.256017   14.785051  -2.818253 -0.667338  ...  -5.619439 -10.547038
# 58465    7.694002   24.956587  -4.730111 -2.687312  ... -10.933144 -17.173665
# ...

# %%
sns.lmplot(y="Amount", x="Time_Hour", fit_reg=False,aspect=1.8,data=df,hue='Class')
plt.title("Amounts by Hour of Frauds and Normal Transactions",fontsize=14,color='r')
plt.show()

# %%
sns.boxplot(x=df['Amount'])

# %%
sns.relplot(x='Class',y='Amount',data=df)

# %%
df.drop('Time',axis=1,inplace=True)

# %%
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V22       V23  \
# ...

# %%
X=df.drop('Class',axis=1)
y=df['Class']

# %%
X
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
# Important feature using ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesClassifier
selection = ExtraTreesClassifier()
selection.fit(X, y)
# Out:
# ExtraTreesClassifier()

# %%
print(selection.feature_importances_)
# Out:
# [0.01298713 0.01272292 0.03110958 0.03546226 0.01311094 0.01220248
#  0.02235868 0.01343774 0.03211549 0.07340916 0.06434259 0.10402186
#  0.01207861 0.12407683 0.01356755 0.08976498 0.14396217 0.03248189
#  0.01325803 0.01385243 0.01775941 0.0137057  0.00923061 0.01280579
#  0.0098072  0.01451882 0.01345871 0.01158225 0.01109917 0.01570902]

# %%
plt.figure(figsize=(15,15))
feat_imp=pd.Series(selection.feature_importances_,index=X.columns)
feat_imp.sort_values(ascending=False).plot(kind='barh')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(X.corr(),annot = True, cmap = "RdYlGn")

# %%
sns.relplot(x='V17',y='V12',hue='Class',data=df,palette='magma')

# %%
sns.relplot(x='V17',y='V14',hue='Class',data=df)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
s=StandardScaler()
X_train=s.fit_transform(X_train)
X_test=s.transform(X_test)

# %%
value=[]
algo=[]
def cross_val_score_model(model,name):
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=10)
    cv_score=cross_val_score(model,X,y,cv=cv).mean()
    print('CV_Score' + ' '+ str(name) +': '+ str(cv_score))
    value.append(cv_score)
    algo.append(name)

cross_val_score_model(LogisticRegression(solver='liblinear',multi_class='auto'),'Logistic Regression')
# Out:
# CV_Score Logistic Regression: 0.9991994663108738

# %%
df[df['Class']==1]
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 541    -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 623    -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4920   -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6108   -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 6329    1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 280143  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 280149 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 281144 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 281674  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
# ...

# %%
from sklearn.metrics import accuracy_score
lr=LogisticRegression(solver='liblinear',multi_class='auto')
lr.fit(X_train,y_train)
lr_y_pred=lr.predict(X_test)
score=accuracy_score(y_test,lr_y_pred)
score
# Out:
# 0.9992977774656788

# %%
X.iloc[45203]
# Out:
# V1           -2.524012
# V2            2.098152
# V3           -4.946075
# V4            6.456588
# V5            3.173921
# V6           -3.058806
# V7           -0.184710
# V8           -0.390420
# V9           -3.649812
# V10          -4.077585
# V11           4.389214
# V12          -5.849558
# V13          -0.750964
# V14         -11.583898
# V15           0.838750
# V16          -1.461029
# V17           0.635694
# V18           0.390150
# V19          -1.063028
# V20          -0.162797
# V21           0.027935
# V22           0.220366
# V23           0.976348
# V24          -0.290539
# V25           1.161002
# V26           0.663954
# V27           0.456023
# V28          -0.405682
# Amount        1.000000
# Time_Hour    11.735278
# Name: 45203, dtype: float64

# %%
a=[[-2.524012,2.098152,-4.946075,6.456588,3.173921,-3.058806,-0.18471,-0.39042,-3.649812,-4.077585,4.389214,-5.849558,-0.750964,-11.583898,0.83875,-1.461029,0.635694,0.39015,-1.063028,-0.162797,0.027935,0.220366,0.976348,-0.290539,1.161002,0.663954,0.456023,-0.405682,1,11.735278
]]
a=s.transform(a)
b=lr.predict(a)
b
# Out:
# array([1], dtype=int64)

# %%
final=pd.DataFrame({'actual':y_test,
                   'predictions':lr_y_pred})

# %%
final
# Out:
#         actual  predictions
# 168367       0            0
# 110270       0            0
# 243562       0            0
# 74702        0            0
# 98416        0            0
# ...        ...          ...
# 201941       0            0
# 244413       0            0
# 50907        0            0
# 240691       0            0
# 79068        0            0
#
# [56962 rows x 2 columns]

# %%
len(final[(final['actual']==1)& (final['predictions']==0)])
# Out:
# 31

# %%
len(final[(final['actual']==0)& (final['predictions']==1)])
# Out:
# 9

# %%
len(final[final['actual']==final['predictions']])
# Out:
# 56922
